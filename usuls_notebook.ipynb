# %%
from music21 import *
from music21.note import Note as noteclass
from music21.chord import Chord as chordclass
from music21.meter import TimeSignature as tsclass
import os, glob
# Out:
# music21: Certain music21 functions might need the optional package matplotlib;
#                   if you run into errors, install it by following the instructions at
#                   http://mit.edu/music21/doc/installing/installAdditional.html

# %%
score = converter.parse('./scores/mxl/Çenber.mxl')
rhythm = score.getElementsByClass('Part')[0].getElementsByClass('Measure')[0]

# %%
for element in rhythm:
  print(element)
# Out:
# <music21.expressions.TextExpression "Düm">
# <music21.layout.SystemLayout>
# <music21.layout.StaffLayout distance None, staffNumber None, staffSize None, staffLines 2>
# <music21.clef.TrebleClef>
# <music21.key.KeySignature of no sharps or flats>
# <music21.meter.TimeSignature 24/4>
# <music21.note.Note F>
# <music21.expressions.TextExpression "Te">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Ke">
# <music21.note.Note D>
# <music21.expressions.TextExpression "Düm">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Düm">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Tek">
# <music21.note.Note D>
# <music21.expressions.TextExpression "Tek">
# <music21.note.Note D>
# <music21.expressions.TextExpression "Tek">
# <music21.note.Note D>
# <music21.expressions.TextExpression "Düm">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Ta">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Hek">
# <music21.chord.Chord D5 F5>
# <music21.expressions.TextExpression "Te">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Ke">
# <music21.note.Note D>
# <music21.expressions.TextExpression "Te">
# <music21.note.Note F>
# <music21.expressions.TextExpression "Ke">
# <music21.note.Note D>
# <music21.bar.Barline type=final>

# %%
class UsulStroke:
  def __init__(self, mnote, stroke, barduration):    
    self.stroketype = stroke.content
    self.duration = mnote.duration.quarterLength
    self.offset = mnote.beat
    self.barduration = barduration
    self.compatoffset = float((mnote.beat - 1)/barduration)
    if isinstance(mnote, chordclass):
      self.hand = "both"
    elif mnote.pitch.name == "F":
      self.hand = "right"
    elif mnote.pitch.name == "D":
      self.hand = "left"
    else:
      self.hand = "unknown"

  def __repr__(self):
    return "UsulStroke"

  def __str__(self):
    return "Stroke:%s, Duration:%s, Hand:%s, Offset:%s(%s)" % (self.stroketype, self.duration, self.hand, self.compatoffset, type(self.compatoffset))

class Usul:
  def __init__(self, usulname, strokes, nbeats):
    self.nbeats = nbeats
    self.usul = usulname
    self.strokes = strokes

  @classmethod
  def usul_from_file(cls, file):
    nbeats = 0
    score = converter.parse(file)
    rhythm = score.getElementsByClass('Part')[0].getElementsByClass('Measure')[0]
    notes = []
    for element in rhythm:
      if isinstance(element, (noteclass, chordclass)):
        notes.append(element)
      if isinstance(element, (tsclass)):
        nbeats = element.beatCount
        
    strokes = rhythm.getElementsByClass('TextExpression')
    usul_name = file.split('/')[-1].split('.mxl')[0].lower().replace('_', ' ')
    strokes_list = []
    for note in range(len(notes)):
      strk = UsulStroke(notes[note], strokes[note], nbeats)
      strokes_list.append(strk)
    return cls(usul_name, strokes_list, nbeats)


  def __iter__(self):
    self.index = 0
    return self

  def __next__(self):
    if self.index < len(self.strokes):
      idx = self.index
      self.index += 1
      return self.strokes[idx]
    else:
      raise StopIteration

  def _repr__(self):
    return "Usul"
  
  def __str__(self):
    return "Usul Object: %s" % (self.usul)

# %%
usuls_files_list = glob.glob('./scores/mxl/*.mxl')
usuls_dict = {}
for usul_file in usuls_files_list:
  usul_name = usul_file.split('/')[-1].split('.mxl')[0].lower().replace('_', ' ')
  if '\\' in usul_name:  # Windows use \ instead of /
        usul_name = usul_name.split('\\')[-1]
  usuls_dict[usul_name] = Usul.usul_from_file(usul_file)

# %%
for usul in usuls_dict.keys():
  print("########## %s ##########" % usul)
  for s in usuls_dict[usul]:
    print(s)
# Out:
# ########## aksak ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:0.5, Hand:right, Offset:0.2222222222222222(<class 'float'>)
# Stroke:Ke, Duration:0.5, Hand:left, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.4444444444444444(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.6666666666666666(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.8888888888888888(<class 'float'>)
# ########## aksak semai ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:0.5, Hand:right, Offset:0.2(<class 'float'>)
# Stroke:Ka, Duration:1.0, Hand:left, Offset:0.3(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.7(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.9(<class 'float'>)
# ########## berefşan ##########
# Stroke:Düm, Duration:4.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.125(<class 'float'>)
# Stroke:Düm, Duration:4.0, Hand:right, Offset:0.1875(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.3125(<class 'float'>)
# Stroke:Düm, Duration:4.0, Hand:right, Offset:0.375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.5625(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.625(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.6875(<class 'float'>)
# Stroke:Ta, Duration:2.0, Hand:right, Offset:0.75(<class 'float'>)
# Stroke:Hek, Duration:2.0, Hand:both, Offset:0.8125(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.875(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.90625(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.96875(<class 'float'>)
# ########## devr-i kebir ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.07142857142857142(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.14285714285714285(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.21428571428571427(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.25(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.2857142857142857(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.32142857142857145(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.35714285714285715(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.42857142857142855(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.5(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5714285714285714(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.6428571428571429(<class 'float'>)
# Stroke:Ta, Duration:2.0, Hand:right, Offset:0.7142857142857143(<class 'float'>)
# Stroke:Hek, Duration:2.0, Hand:both, Offset:0.7857142857142857(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.8571428571428571(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.8928571428571429(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9285714285714286(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.9642857142857143(<class 'float'>)
# ########## düyek ##########
# Stroke:Dum, Duration:0.5, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.125(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.375(<class 'float'>)
# Stroke:Dum, Duration:1.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.75(<class 'float'>)
# ########## evfer ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:0.5, Hand:right, Offset:0.2222222222222222(<class 'float'>)
# Stroke:Ke, Duration:0.5, Hand:left, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.4444444444444444(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.6666666666666666(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.7777777777777778(<class 'float'>)
# ########## fahte ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.1(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.15(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.2(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.3(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.4(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Ta, Duration:2.0, Hand:right, Offset:0.6(<class 'float'>)
# Stroke:Hek, Duration:2.0, Hand:both, Offset:0.7(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.8(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.85(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.95(<class 'float'>)
# ########## hafif ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.03125(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.0625(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.125(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.15625(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.1875(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.25(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.3125(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.34375(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.375(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.40625(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.4375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.5625(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.59375(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.625(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.65625(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.6875(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.71875(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.75(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.78125(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.8125(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.84375(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.875(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.96875(<class 'float'>)
# ########## havi ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.0625(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.09375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.125(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.1875(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.21875(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.25(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.3125(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.34375(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.40625(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.4375(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.53125(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.5625(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.59375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.625(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.6875(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.75(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.8125(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.875(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.90625(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.96875(<class 'float'>)
# ########## muhammes ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.0625(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.09375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.125(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.1875(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.25(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.3125(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.375(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.4375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.46875(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.5625(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.625(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.65625(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.6875(<class 'float'>)
# Stroke:Ta, Duration:2.0, Hand:right, Offset:0.75(<class 'float'>)
# Stroke:Hek, Duration:2.0, Hand:both, Offset:0.8125(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.875(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.90625(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9375(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.96875(<class 'float'>)
# ########## oynak ##########
# Stroke:Düm, Duration:0.5, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.1111111111111111(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.2222222222222222(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.5555555555555556(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.7777777777777778(<class 'float'>)
# ########## raks aksağı ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:1.5, Hand:left, Offset:0.2222222222222222(<class 'float'>)
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.5555555555555556(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.7777777777777778(<class 'float'>)
# ########## semai ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.6666666666666666(<class 'float'>)
# ########## sofyan ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.75(<class 'float'>)
# ########## türk aksağı ##########
# Stroke:Düm, Duration:1.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.4(<class 'float'>)
# Stroke:Ke, Duration:0.5, Hand:left, Offset:0.8(<class 'float'>)
# ########## yürük semai ##########
# Stroke:Düm, Duration:0.5, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.16666666666666666(<class 'float'>)
# Stroke:Tek, Duration:0.5, Hand:left, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Düm, Duration:0.5, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Tek, Duration:1.0, Hand:left, Offset:0.6666666666666666(<class 'float'>)
# ########## çenber ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.08333333333333333(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.125(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.16666666666666666(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.25(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.3333333333333333(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.4166666666666667(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.5(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5833333333333334(<class 'float'>)
# Stroke:Ta, Duration:2.0, Hand:right, Offset:0.6666666666666666(<class 'float'>)
# Stroke:Hek, Duration:2.0, Hand:both, Offset:0.75(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.8333333333333334(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.875(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.9166666666666666(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.9583333333333334(<class 'float'>)
# ########## çifte düyek ##########
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.0(<class 'float'>)
# Stroke:Tek, Duration:4.0, Hand:left, Offset:0.125(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.375(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.5(<class 'float'>)
# Stroke:Düm, Duration:2.0, Hand:right, Offset:0.625(<class 'float'>)
# Stroke:Tek, Duration:2.0, Hand:left, Offset:0.75(<class 'float'>)
# Stroke:Te, Duration:1.0, Hand:right, Offset:0.875(<class 'float'>)
# Stroke:Ke, Duration:1.0, Hand:left, Offset:0.9375(<class 'float'>)
